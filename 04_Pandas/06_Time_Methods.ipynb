# %%
from datetime import datetime

# %%
my_year = 2024
my_month = 1
my_day = 22
my_hour = 19
my_minute = 42
my_second = 11

# %%
my_date = datetime(year=my_year,day = my_day,month = my_month)

# %%
my_date
# Out:
# datetime.datetime(2024, 1, 22, 0, 0)

# %%
my_date.day
# Out:
# 22

# %%
my_date = datetime(year=my_year,day = my_day,month = my_month, hour = my_hour,minute = my_minute, second = my_second)

# %%
my_date.hour
# Out:
# 19

# %%
my_date
# Out:
# datetime.datetime(2024, 1, 22, 19, 42, 11)

# %%
import pandas as pd

# %%
myser = pd.Series(['Nov 3, 2024','2024-01-01','02-03-2020', None])
myser
# Out:
# 0    Nov 3, 2024
# 1     2024-01-01
# 2     02-03-2020
# 3           None
# dtype: object

# %%
type(myser[0])
# Out:
# str

# %%
dt1 = pd.to_datetime(myser, format='mixed',dayfirst=False)


#Dayfirst = True means it is in format dd-mm-yyyy
#Dayfirst = False means it is in format mm-dd-yyyy

# %%
dt1[2]
# Out:
# Timestamp('2020-02-03 00:00:00')

# %%
#Custom Time String
strange_date = '12-*--Dec-+--2024'
pd.to_datetime(strange_date,format='%d-*--%b-+--%Y')
# Out:
# Timestamp('2024-12-12 00:00:00')
